# %%
a, c, X, Z = var ('a, c, X, Z')

# %%
f = x**5 - 4*a*x**3 + 2*x*a**2 + x*c - 2*x**4 + 8*a*x**2 - 4*a**2 - 2*c; f
# Out:
# x^5 - 4*a*x^3 - 2*x^4 + 2*a^2*x + 8*a*x^2 - 4*a^2 + c*x - 2*c

# %%
y = f.sqrt(); y
# Out:
# sqrt(x^5 - 4*a*x^3 - 2*x^4 + 2*a^2*x + 8*a*x^2 - 4*a^2 + c*x - 2*c)

# %%
F = ((X - 2) * (X**4 - 4*a*X**2 + 2*a**2 + c)); F
# Out:
# (X^4 - 4*X^2*a + 2*a^2 + c)*(X - 2)

# %%
aValue = 1;
cValue = 7;
F.expand()
# Out:
# X^5 - 2*X^4 - 4*X^3*a + 8*X^2*a + 2*X*a^2 - 4*a^2 + X*c - 2*c

# %%
F = F.subs({ a : aValue }).subs({ c : cValue }).subs({ X : x-Z});
y = y.subs({ a : aValue }).subs({ c : cValue }); F.expand()
# Out:
# -Z^5 + 5*Z^4*x - 10*Z^3*x^2 + 10*Z^2*x^3 - 5*Z*x^4 + x^5 - 2*Z^4 + 8*Z^3*x - 12*Z^2*x^2 + 8*Z*x^3 - 2*x^4 + 4*Z^3 - 12*Z^2*x + 12*Z*x^2 - 4*x^3 + 8*Z^2 - 16*Z*x + 8*x^2 - 9*Z + 9*x - 18

# %%
E = F.sqrt().series(Z, 11).expand(); E
# Out:
# (sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)) + (-5/2*x^4/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 4*x^3/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 6*x^2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) - 8*x/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) - 9/2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18))*Z + (-25/8*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 10*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 7*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 44*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 5*x^3/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 11/4*x^4/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 6*x^2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 66*x^3/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 6*x/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) - 5*x^2/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 4/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) - 36*x/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 81/8/(x^5 - 2*x^4 - 4*x^3
# ...

# %%
A2 = -Z**2;
A3 = F.sqrt().series(Z, 3);
A4 = F.sqrt().series(Z, 4);

# %%
A2
# Out:
# -Z^2

# %%
A3
# Out:
# (sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)) + (-1/2*(5*x^4 - 8*x^3 - 12*x^2 + 16*x + 9)/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18))*Z + (-1/8*((5*x^4 - 8*x^3 - 12*x^2 + 16*x + 9)^2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) - 8*sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)*(5*x^3 - 6*x^2 - 6*x + 4))/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18))*Z^2 + Order(Z^3)

# %%
A4
# Out:
# (sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)) + (-1/2*(5*x^4 - 8*x^3 - 12*x^2 + 16*x + 9)/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18))*Z + (-1/8*((5*x^4 - 8*x^3 - 12*x^2 + 16*x + 9)^2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) - 8*sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)*(5*x^3 - 6*x^2 - 6*x + 4))/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18))*Z^2 + (-1/16*(16*sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)*(5*x^2 - 4*x - 2) + (5*x^4 - 8*x^3 - 12*x^2 + 16*x + 9)*((5*x^4 - 8*x^3 - 12*x^2 + 16*x + 9)^2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) - 8*sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)*(5*x^3 - 6*x^2 - 6*x + 4))/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18))/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18))*Z^3 + Order(Z^4)

# %%
B2 = 0;
B3 = 1;
B4 = 1;

# %%
C3 = 0;
for i in range(3, 11):
    C3 += E.coefficient(Z, i) * Z**(i-3);

# %%
C3
# Out:
# -125/16*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 75/2*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 1/262144*(23740234375*x^40/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) - 379843750000*x^39/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) + 2165109375000*x^38/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) - 2704487500000*x^37/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) - 100546875000*x^35/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(17/2) - 24195667031250*x^36/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) + 1407656250000*x^34/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(17/2) + 101990052450000*x^35/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) - 6700443750000*x^33/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(17/2) + 4603159275000*x^34/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) + 3574642500000*x^32/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(17/2) - 842042924580000*x^33/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) + 171600000000*x^30/(x^5 - 2*x^4 - 4*x^3
# ...

# %%
C4 = 0;
for i in range(4, 11):
    C4 += E.coefficient(Z, i) * Z**(i-4);

# %%
C4
# Out:
# -3125/128*x^16/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 625/4*x^15/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 1125/8*x^14/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 2075/2*x^13/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 375/8*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 67855/32*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 825/4*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 9735/4*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 1/262144*(23740234375*x^40/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) - 379843750000*x^39/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) + 2165109375000*x^38/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) - 2704487500000*x^37/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) - 100546875000*x^35/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(17/2) - 24195667031250*x^36/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(19/2) + 1407656250000*x^34/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(17/2) + 101990052450000*x^
# ...

# %%
v = [0, 0]
for j in range(2, 7):
    v.append(j**2 - j - 2)
v
# Out:
# [0, 0, 0, 4, 10, 18, 28]

# %%
psi = [0, 0, 1]
psi.append( ( 2*y )**2 );
psi.append( ( 2*y )**5 * E.coefficient(Z, 3) );
psi.append( ( 2*y )**(v[5]/2) * (E.coefficient(Z, 4) * E.coefficient(Z, 6) - E.coefficient(Z, 5)**2) );
psi.append( ( 2*y )**(v[6]/2) * (E.coefficient(Z, 3) * E.coefficient(Z, 5) - E.coefficient(Z, 4)**2) );

# %%
psi[3]
# Out:
# 4*x^5 - 8*x^4 - 16*x^3 + 32*x^2 + 36*x - 72

# %%
psi[4]
# Out:
# -2*(125*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 600*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 60*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 3568*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 200*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 3309*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 560*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 8304*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 336*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 9816*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 1760*x^4/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 10272*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 80*x^2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 88*x^3/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 11025*x^4/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 64*x/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 1584*x^2/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 8216*x^3/(x^5 - 2*x^4 
# ...

# %%
delta = [0, 0, 0, 0, 0, 0]

D2 = -Z**2;
D2 = D2.subs( {Z : 4*y**2*Z} )
delta[2]=( (2*y)**(v[2]) * D2 )

D3 = 0;
supD3 = ( 2 * A3 * C3 ).expand();

for i in range(0, 3):
    D3 += supD3.coefficient(Z, i) * Z**i;

D3 = 2 * (E.coefficient(Z, 0) * E.coefficient(Z, 5) + E.coefficient(Z, 1) * E.coefficient(Z, 4) + E.coefficient(Z, 2) * E.coefficient(Z, 3) ) * Z**2 + 2 * (E.coefficient(Z, 0) * E.coefficient(Z, 4) + E.coefficient(Z, 1) * E.coefficient(Z, 3)) * Z + 2 * E.coefficient(Z, 0) * E.coefficient(Z, 3);
D3 = D3.subs( {Z : 4*y**2*Z} );

delta[3] = (2*y)**(v[3]) * D3;

D4 = 2 * (E.coefficient(Z, 0) * E.coefficient(Z, 6) + E.coefficient(Z, 1) * E.coefficient(Z, 5) + E.coefficient(Z, 2) * E.coefficient(Z, 4)) * Z**2 + 2 * (E.coefficient(Z, 0) * E.coefficient(Z, 5) + E.coefficient(Z, 1) * E.coefficient(Z, 4)) * Z + 2 * E.coefficient(Z, 0) * E.coefficient(Z, 4);
D4 = D4.subs( {Z : 4*y**2*Z} );

delta[4] = (2*y)**(v[4]) * D4;

# %%
D2
# Out:
# -16*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2*Z^2

# %%
D3
# Out:
# 1/8*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2*(2*(125*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 600*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 60*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 3568*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 200*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 3309*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 560*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 8304*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 336*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 9816*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 1760*x^4/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 10272*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 80*x^2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 88*x^3/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 11025*x^4/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 64*x/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 1584*x^2/(x^5 - 2*x^4 - 4*x^3 + 8
# ...

# %%
D4
# Out:
# 1/32*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2*((3125*x^16/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 20000*x^15/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 18000*x^14/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 132800*x^13/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 6000*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 271420*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 26400*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 311520*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 2400*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 1064240*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 128448*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 258240*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 3200*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 105888*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 2088690*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 7680*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18
# ...

# %%
delta[2]
# Out:
# -16*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2*Z^2

# %%
delta[3]
# Out:
# (2*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2*(2*(125*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 600*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 60*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 3568*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 200*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 3309*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 560*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 8304*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 336*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 9816*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 1760*x^4/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 10272*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 80*x^2/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 88*x^3/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 11025*x^4/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 64*x/sqrt(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 1584*x^2/(x^5 - 2*x^4 - 4*x^3 + 8*
# ...

# %%
delta[4]
# Out:
# 16*(2*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2*((3125*x^16/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 20000*x^15/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 18000*x^14/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 132800*x^13/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 6000*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 271420*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 26400*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 311520*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 2400*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 1064240*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 128448*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 258240*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) + 3200*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) + 105888*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 2088690*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(7/2) - 7680*x^5/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 1
# ...

# %%
d2 = delta[3].coefficient(Z, 2);
d1 = delta[3].coefficient(Z, 1);
d0 = delta[3].coefficient(Z, 0);

# %%
d2.expand()
# Out:
# -256*x^20 + 2048*x^19 - 2048*x^18 - 24576*x^17 + 60416*x^16 + 139264*x^15 - 569344*x^14 - 327680*x^13 + 3054080*x^12 - 577536*x^11 - 10772480*x^10 + 7553024*x^9 + 25189376*x^8 - 28827648*x^7 - 37343232*x^6 + 63700992*x^5 + 26189568*x^4 - 82114560*x^3 + 7464960*x^2 + 53747712*x - 26873856

# %%
d1.expand()
# Out:
# -625*x^31/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 + 7750*x^30/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 - 27600*x^29/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 - 44960*x^28/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 + 2000*x^26/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2 + 512769*x^27/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 - 20800*x^25/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2 - 548550*x^26/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 + 53600*x^24/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2 - 3841612*x^25/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 + 166016*x^23/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2 + 9611656*x^24/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 - 1600*x^21/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) - 993392*x^22/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2 + 14137851*x^23/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^3 + 13440*x^20/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18) + 84672*x^21/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^2 - 69614338*x^22/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 
# ...

# %%
d0.expand()
# Out:
# -10*x^12 + 48*x^11 + 40*x^10 - 480*x^9 + 250*x^8 + 1120*x^7 + 2320*x^6 - 11840*x^5 + 4050*x^4 + 33840*x^3 - 51480*x^2 + 15264*x + 8910

# %%
f = open("l_3_delta0.txt", "w"); f.write(str(d0)); f.close()
f = open("l_3_delta1.txt", "w"); f.write(str(d1)); f.close()
f = open("l_3_delta2.txt", "w"); f.write(str(d2)); f.close()

# %%
epsilon = [0, 0, 0, 0, 0, 0]

# %%
epsilon[3] = (y * Z * (psi[2]**2 * delta[4] - psi[4]**2 * delta[2]) / (psi[2] * psi[3]**2*psi[4]) ).expand(); epsilon[3]
# Out:
# 300000*Z^3*x^58/((x^25 - 10*x^24 + 20*x^23 + 120*x^22 - 515*x^21 - 482*x^20 + 5240*x^19 - 2160*x^18 - 31590*x^17 + 38140*x^16 + 125336*x^15 - 246640*x^14 - 320070*x^13 + 999100*x^12 + 416320*x^11 - 2801152*x^10 + 358245*x^9 + 5472270*x^8 - 2966220*x^7 - 7118280*x^6 + 6765849*x^5 + 5124870*x^4 - 8135640*x^3 - 524880*x^2 + 4723920*x - 1889568)*(x^20 - 8*x^19 + 8*x^18 + 96*x^17 - 236*x^16 - 544*x^15 + 2224*x^14 + 1280*x^13 - 11930*x^12 + 2256*x^11 + 42080*x^10 - 29504*x^9 - 98396*x^8 + 112608*x^7 + 145872*x^6 - 248832*x^5 - 102303*x^4 + 320760*x^3 - 29160*x^2 - 209952*x + 104976)*(125*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 600*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 60*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 3568*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 200*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 3309*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 560*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 8304*x^7/(
# ...

# %%
epsilon[3]
# Out:
# 300000*Z^3*x^58/((x^25 - 10*x^24 + 20*x^23 + 120*x^22 - 515*x^21 - 482*x^20 + 5240*x^19 - 2160*x^18 - 31590*x^17 + 38140*x^16 + 125336*x^15 - 246640*x^14 - 320070*x^13 + 999100*x^12 + 416320*x^11 - 2801152*x^10 + 358245*x^9 + 5472270*x^8 - 2966220*x^7 - 7118280*x^6 + 6765849*x^5 + 5124870*x^4 - 8135640*x^3 - 524880*x^2 + 4723920*x - 1889568)*(x^20 - 8*x^19 + 8*x^18 + 96*x^17 - 236*x^16 - 544*x^15 + 2224*x^14 + 1280*x^13 - 11930*x^12 + 2256*x^11 + 42080*x^10 - 29504*x^9 - 98396*x^8 + 112608*x^7 + 145872*x^6 - 248832*x^5 - 102303*x^4 + 320760*x^3 - 29160*x^2 - 209952*x + 104976)*(125*x^12/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 600*x^11/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 60*x^10/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 3568*x^9/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) - 200*x^7/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 3309*x^8/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(5/2) + 560*x^6/(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2) - 8304*x^7/(
# ...

# %%
#Epsilon[3] = Epsilon[3] mod Delta[3] (результаты получены на Maple)
epsilon[3] = -(1/128)*(145*Z*x^24-1392*Z*x^23+2472*Z*x^22+16288*Z*x^21-70842*Z*x^20+56208*Z*x^19-22*x^20+13320*Z*x^18+176*x^19+353376*Z*x^17-120*x^18+679455*Z*x^16-2400*x^17-6878048*Z*x^15+6906*x^16-501360*Z*x^14-9024*x^15+60424512*Z*x^13+57504*x^14-92347628*Z*x^12-199296*x^13-138692064*Z*x^11-54588*x^12+487945488*Z*x^10+1482272*x^11-95816256*Z*x^9-1906000*x^10-1266553665*Z*x^8-4675392*x^9+1806882768*Z*x^7+15702420*x^8+190119240*Z*x^6-8435520*x^7-2999895264*Z*x^5-31489632*x^6+3115291590*Z*x^4+64326528*x^5-391820976*Z*x^3-36094158*x^4-1767393432*Z*x^2-25885008*x^3+1541677536*Z*x+49051656*x^2-448719183*Z-29204064*x+7583058)/((x^10-4*x^9-4*x^8+32*x^7+2*x^6-136*x^5+64*x^4+288*x^3-207*x^2-324*x+324)*(x^5-2*x^4-4*x^3+8*x^2+9*x-18)^(3/2))

# %%
epsilon[3]
# Out:
# -1/128*(145*Z*x^24 - 1392*Z*x^23 + 2472*Z*x^22 + 16288*Z*x^21 - 70842*Z*x^20 + 56208*Z*x^19 - 22*x^20 + 13320*Z*x^18 + 176*x^19 + 353376*Z*x^17 - 120*x^18 + 679455*Z*x^16 - 2400*x^17 - 6878048*Z*x^15 + 6906*x^16 - 501360*Z*x^14 - 9024*x^15 + 60424512*Z*x^13 + 57504*x^14 - 92347628*Z*x^12 - 199296*x^13 - 138692064*Z*x^11 - 54588*x^12 + 487945488*Z*x^10 + 1482272*x^11 - 95816256*Z*x^9 - 1906000*x^10 - 1266553665*Z*x^8 - 4675392*x^9 + 1806882768*Z*x^7 + 15702420*x^8 + 190119240*Z*x^6 - 8435520*x^7 - 2999895264*Z*x^5 - 31489632*x^6 + 3115291590*Z*x^4 + 64326528*x^5 - 391820976*Z*x^3 - 36094158*x^4 - 1767393432*Z*x^2 - 25885008*x^3 + 1541677536*Z*x + 49051656*x^2 - 448719183*Z - 29204064*x + 7583058)/((x^10 - 4*x^9 - 4*x^8 + 32*x^7 + 2*x^6 - 136*x^5 + 64*x^4 + 288*x^3 - 207*x^2 - 324*x + 324)*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2))

# %%
e1 = epsilon[3].coefficient(Z, 1);
e0 = epsilon[3].coefficient(Z, 0);

# %%
e1
# Out:
# -1/128*(145*x^24 - 1392*x^23 + 2472*x^22 + 16288*x^21 - 70842*x^20 + 56208*x^19 + 13320*x^18 + 353376*x^17 + 679455*x^16 - 6878048*x^15 - 501360*x^14 + 60424512*x^13 - 92347628*x^12 - 138692064*x^11 + 487945488*x^10 - 95816256*x^9 - 1266553665*x^8 + 1806882768*x^7 + 190119240*x^6 - 2999895264*x^5 + 3115291590*x^4 - 391820976*x^3 - 1767393432*x^2 + 1541677536*x - 448719183)/((x^10 - 4*x^9 - 4*x^8 + 32*x^7 + 2*x^6 - 136*x^5 + 64*x^4 + 288*x^3 - 207*x^2 - 324*x + 324)*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2))

# %%
e0
# Out:
# 1/64*(11*x^20 - 88*x^19 + 60*x^18 + 1200*x^17 - 3453*x^16 + 4512*x^15 - 28752*x^14 + 99648*x^13 + 27294*x^12 - 741136*x^11 + 953000*x^10 + 2337696*x^9 - 7851210*x^8 + 4217760*x^7 + 15744816*x^6 - 32163264*x^5 + 18047079*x^4 + 12942504*x^3 - 24525828*x^2 + 14602032*x - 3791529)/((x^10 - 4*x^9 - 4*x^8 + 32*x^7 + 2*x^6 - 136*x^5 + 64*x^4 + 288*x^3 - 207*x^2 - 324*x + 324)*(x^5 - 2*x^4 - 4*x^3 + 8*x^2 + 9*x - 18)^(3/2))

# %%
f = open("l_3_epsilon0.txt", "w"); f.write(str(e0)); f.close()
f = open("l_3_epsilon1.txt", "w"); f.write(str(e1)); f.close()

# %%
d0 = ((9*(4*x^12/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+5*x^11/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+5*x^10/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+4*x^9/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+9*x^7/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(3/2)+2*x^8/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+10*x^6/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(3/2)+x^7/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+6*x^5/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(3/2)+4*x^6/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+9*x^5/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+3*x^2/sqrt(x^5+9*x^4+7*x^3+8*x^2+9*x+4)+8*x^4/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+2*x/sqrt(x^5+9*x^4+7*x^3+8*x^2+9*x+4)+x^3/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+1/sqrt(x^5+9*x^4+7*x^3+8*x^2+9*x+4)+8*x/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(3/2)+3*x^2/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+9/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(3/2)+5*x/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)+3/(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)))*(x^5+9*x^4+7*x^3+8*x^2+9*x+4)^(5/2)).expand();

# %%
d0
# Out:
# 144*x^12 + 1368*x^11 + 4374*x^10 + 7506*x^9 + 10953*x^8 + 14265*x^7 + 15003*x^6 + 13680*x^5 + 11178*x^4 + 7506*x^3 + 4356*x^2 + 1998*x + 495
